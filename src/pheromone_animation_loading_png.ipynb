# %%
# %matplotlib inline

# %% [markdown]
# # Animated image using a precomputed list of images

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from IPython import display


path = "/home/sub/catkin_ws/src/Turtlebot3_Pheromone/src/plot_script/20210408-002719"

fig, ax = plt.subplots()




        
def pherogrid(n, time):
    # n - num of robots (int)
    # time - time_step (int)
    grids = [None]*n
    for i in range(n):
        with open(path + '{}_{}.npy'.format(i, time), 'rb') as f:
            grids[i] = np.load(f)
    sum_grids = np.maximum(grids[0], grids[1])
    return sum_grids

# %%
a = pherogrid(2, 0.1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-d0ce830a55cf> in <module>()
# ----> 1 a = pherogrid(2, 0.1)
#
# <ipython-input-35-851790408075> in pherogrid(n, time)
#      20         with open(path + '{}_{}.npy'.format(i, time), 'rb') as f:
#      21             grids[i] = np.load(f)
# ---> 22     sum_grids = np.maximum(grid[0], grid[1])
#      23     return sum_grids
#      24
#
# NameError: name 'grid' is not defined

# %%
    

x = np.linspace(0, 2 * np.pi, 120)
y = np.linspace(0, 2 * np.pi, 100).reshape(-1, 1)

# ims is a list of lists, each row is a list of artists to draw in the
# current frame; here we are just animating one artist, the image, in
# each frame
n = 2
ims = []
for i in range(28):
        image = plt.imread(path+"/20210408-002719_{}.png".format(i))
        im = ax.imshow(image, animated=True)
        ims.append([im])
print(len(ims))
ani = animation.ArtistAnimation(fig, ims, interval=70, blit=True,
                                repeat_delay=1000)

# To save the animation, use e.g.
#
# ani.save("movie.mp4")
#
# or
#
# writer = animation.FFMpegWriter(
#     fps=15, metadata=dict(artist='Me'), bitrate=1800)
# ani.save("movie.mp4", writer=writer)

plt.show()
# Out:
# 28

# %%
video = ani.to_html5_video()
html = display.HTML(video)
display.display(html)
plt.close()
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>
