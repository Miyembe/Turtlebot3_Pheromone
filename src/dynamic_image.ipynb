# %%
# %matplotlib inline

# %% [markdown]
# # Animated image using a precomputed list of images

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import sys
print(sys.path)
from IPython import display

fig, ax = plt.subplots()


def f(x, y):
    return np.sin(x) + np.cos(y)

x = np.linspace(0, 2 * np.pi, 120)
y = np.linspace(0, 2 * np.pi, 100).reshape(-1, 1)

# ims is a list of lists, each row is a list of artists to draw in the
# current frame; here we are just animating one artist, the image, in
# each frame
ims = []
for i in range(60):
    x += np.pi / 15.
    y += np.pi / 20.
    im = ax.imshow(f(x, y), animated=True)
    ax.scatter(25, 50, s=50, c='red', marker='o')
    if i == 0:
        ax.imshow(f(x, y))  # show an initial one first
    ims.append([im])

ani = animation.ArtistAnimation(fig, ims, interval=50, blit=True,
                                repeat_delay=1000)

# To save the animation, use e.g.
#
# ani.save("movie.mp4")
#
# or
#
# writer = animation.FFMpegWriter(
#     fps=15, metadata=dict(artist='Me'), bitrate=1800)
# ani.save("movie.mp4", writer=writer)

plt.show()
# Out:
# ['', '/home/sub/catkin_ws/devel/lib/python2.7/dist-packages', '/home/sub/workspace/devel/lib/python2.7/dist-packages', '/home/sub/mrs_workspace/devel/lib/python2.7/dist-packages', '/opt/ros/melodic/lib/python2.7/dist-packages', '/home/sub/mpe_env/lib/python2.7', '/home/sub/mpe_env/lib/python2.7/plat-x86_64-linux-gnu', '/home/sub/mpe_env/lib/python2.7/lib-tk', '/home/sub/mpe_env/lib/python2.7/lib-old', '/home/sub/mpe_env/lib/python2.7/lib-dynload', '/usr/lib/python2.7', '/usr/lib/python2.7/plat-x86_64-linux-gnu', '/usr/lib/python2.7/lib-tk', '/home/sub/mpe_env/local/lib/python2.7/site-packages', '/home/sub/mpe_env/lib/python2.7/site-packages', '/home/sub/mpe_env/local/lib/python2.7/site-packages/IPython/extensions', '/home/sub/.ipython']

# %%
video = ani.to_html5_video()
html = display.HTML(video)
display.display(html)
plt.close()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-3-3913066d8c63> in <module>()
# ----> 1 video = ani.to_html5_video()
#       2 html = display.HTML(video)
#       3 display.display(html)
#       4 plt.close()
#
# /home/sub/mpe_env/local/lib/python2.7/site-packages/matplotlib/animation.pyc in to_html5_video(self, embed_limit)
#    1347                 # We create a writer manually so that we can get the
#    1348                 # appropriate size for the tag
# -> 1349                 Writer = writers[rcParams['animation.writer']]
#    1350                 writer = Writer(codec='h264',
#    1351                                 bitrate=rcParams['animation.bitrate'],
#
# /home/sub/mpe_env/local/lib/python2.7/site-packages/matplotlib/animation.pyc in __getitem__(self, name)
#     171         except KeyError:
#     172             raise RuntimeError(
# --> 173                 'Requested MovieWriter ({}) not available'.format(name))
#     174
#     175
#
# RuntimeError: Requested MovieWriter (ffmpeg) not available
